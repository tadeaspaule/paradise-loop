# %% [markdown]
# # Paradise Loop - Training file
# ## AI that generates a 'Paradise Lost'-esque poem

# %%
from tensorflow import keras
import numpy as np
import random, sys,os

# %% [markdown]
# ### Getting the Paradise Lost text data
# You can find the file I used at http://www.gutenberg.org/cache/epub/26/pg26.txt <br>
# I did a bit of preprocessing, removing the intro text and the licence at the end

# %%
path = 'paradise-lost.txt'
text = open(path).read().lower()
print("Corpus length:",len(text))
# Out:
# Corpus length: 453692

# %% [markdown]
# ### Extracting the training data
# The training data is sequences of characters of a given length (in this case 80), and the correct answers are the characters that follow this sequence.

# %%
maxlen = 80 # length of sequence (in characters) the model will look at
step = 3 # new sequence every X characters
sentences = []
next_chars = []

for i in range(0,len(text)-maxlen,step):
    sentences.append(text[i:i+maxlen])
    next_chars.append(text[i+maxlen])

# Making a char index
chars = sorted(list(set(text)))
char_index = dict((char, chars.index(char)) for char in chars)

# One-hot-encoding the sequences
x = np.zeros((len(sentences),maxlen,len(chars)),dtype=np.bool)
y = np.zeros((len(sentences),len(chars)),dtype=np.bool)

for i, sentence in enumerate(sentences):
    for j, char in enumerate(sentence):
        x[i,j,char_index[char]] = 1
        y[i,char_index[next_chars[i]]] = 1

# %% [markdown]
# ### Building the model
# In this case, I used two LSTM layers, followed by a Dense output layer.

# %%
model = keras.models.Sequential()
model.add(keras.layers.LSTM(128,input_shape=(maxlen,len(chars)),return_sequences=True,recurrent_dropout=0.3))
model.add(keras.layers.LSTM(64,recurrent_dropout=0.3))
model.add(keras.layers.Dense(len(chars),activation='softmax'))

optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy',optimizer=optimizer)

# %% [markdown]
# ### Defining a method to sample the next character
# The model's output is a probability tensor of size len(chars).<br>
# This sampling method gives us more control over which character is picked from this tensor, by using 'temperature'.<br>
# A temperature 1 means weighted randomness, so a char with value 0.3 gets picked 30% of the time.
# A temperature of 0 means always picking the char with the highest value
# This is a spectrum, so try out different values between 0 and 1

# %%
def sample(preds,temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    if (temperature == 0):
        # Avoiding a division by 0 error
        return np.argmax(preds)
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1,preds,1)
    return np.argmax(probas)

# %% [markdown]
# ### Training the model
# Here the model is trained<br>
# Some output is generated at each epoch, so we can see how to model is doing.<br>
# The model can also be saved at every epoch, so that we can go back to better performing models afterwards.

# %%
gen_length = 200 # How many chars to generate
save_every = 1 # How often to save the model
temperatures_to_try = [0.2,0.5,1.0] # Which temperatures to showcase during training
                                    # You can use different ones afterwards, this is for monitoring

model_dir = "paradise_loop_models"  # If you change this, make sure to change it in the text generation file too
try:
    os.mkdir(model_dir)
except:
    print("Directory",model_dir,"exists, adding files there")
for epoch in range(1,30):
    print("\n\nEpoch",epoch)
    callbacks = []
    if epoch % save_every == 0:
        callbacks = [keras.callbacks.ModelCheckpoint(filepath=(model_dir+"/epoch_'+str(epoch)+'_2lstms.hdf5"),verbose=0)]
    model.fit(x,y,batch_size=128,epochs=1,callbacks=callbacks)
    
    for temperature in temperatures_to_try:
        print("\nTemperature:",temperature)
        
         # Picking a random starting sequence
        start_i = random.randint(0,len(text)-maxlen-1)
        generated_text = text[start_i:start_i+maxlen]
        print("Generating with starting sequence: \""+generated_text + "\"")
        sys.stdout.write(generated_text)
        for i in range(gen_length):
            # Sampled holds the last MAXLEN characters
            sampled = np.zeros((1,maxlen,len(chars)))
            for j, char in enumerate(generated_text):
                sampled[0,j,char_index[char]] = 1.
            
            preds = model.predict(sampled,verbose=0)[0] # gets the next character (in one-hot-encode form)
            next_index = sample(preds,temperature) # gets index of next character (as int)
            next_char = chars[next_index]
            
            # Updates the 'generated_text' variable
            generated_text = generated_text[1:] + next_char
            
            # Writes the next char
            sys.stdout.write(next_char)
# Out:
# Epoch 1
# Epoch 1/1
# 151204/151204 [==============================] - 231s 2ms/step - loss: 2.1444
#
# Temperature: 0.2
# Generating with starting sequence: " nd pile up every stone
# of lustre from the brook, in memorie,
# or monument to ages "
# nd pile up every stone
# of lustre from the brook, in memorie,
# or monument to ages of the to the sear the sear the sole and the sear the sole the fart the sear the seare the sear the solated the core the sear shall the sear the fart the sore the sole the sate the brie the selm the
# Temperature: 0.5
# Generating with starting sequence: "
# glorie and praise, whose wisdom had ordain’d
# good out of evil to create, in ste "
#
# glorie and praise, whose wisdom had ordain’d
# good out of evil to create, in sterpar stay,
# and this with hen sight his light the vall with shall what lid to amper the lowes and deash and which som when subfire the mast discelse the god whom as pire the  the fall with lat resing t
# Temperature: 1.0
# Generating with starting sequence: " n drie ground appeers, and from his arke
# the ancient sire descends with all his  "
# n drie ground appeers, and from his arke
# the ancient sire descends with all his res with agaer of in of eninor may sporle that in fixiat
# yew thrond knew but his od, shighion with when is of pame i bester in the son on the blimt and shalo asf else these fnigat, their on at to us i
#
# Epoch 2
# Epoch 1/1
# 151204/151204 [==============================] - 247s 2ms/step - loss: 1.8662
#
# Temperature: 0.2
# Generating with starting sequence: " ing sin and death, his two maine armes,
# and fix farr deeper in his head thir sti "
# ing sin and death, his two maine armes,
# and fix farr deeper in his head thir still things the still things though and though and heav’n, and so the son though things though the son the so the shall the son the stand the so though with things and though the stood though though the
# Temperature: 0.5
# Generating with starting sequence: " ngels brought,
# to pales, or pomona, thus adornd,
# likest she seemd, pomona when s "
# ngels brought,
# to pales, or pomona, thus adornd,
# likest she seemd, pomona when shall though thine yet pure and staine, and his do on though shall vain, whom the mon; and the love, whom things, and call’d his can had, which though heav’ns, things boring man with day in with who ho
# Temperature: 1.0
# Generating with starting sequence: "  heav’n of heav’ns i have presum’d,
# an earthlie guest, and drawn empyreal aire,
#  "
#  heav’n of heav’ns i have presum’d,
# an earthlie guest, and drawn empyreal aire,
# or tan,
# and all first
# of wand, which vighthain, which the dest
# who lat and nay ynt
# ocfount will naticlafiging
# compatitie preturnante
# lost, and glorie.
# hides
# and pitrupt implay trigce wings, now sweet.
#
# Epoch 3
# Epoch 1/1
# 151204/151204 [==============================] - 251s 2ms/step - loss: 1.7967
#
# Temperature: 0.2
# Generating with starting sequence: " oule.
# but come, for thou, be sure, shalt give account
# to him who sent us, whose  "
# oule.
# but come, for thou, be sure, shalt give account
# to him who sent us, whose the seems the state and whom the son the seem the seems of more the for the self the son the for the seems the fore the self the self the self the self the serve the seemd the seems and the son the st
# Temperature: 0.5
# Generating with starting sequence: " rd in oreb since perhaps
# when god descended, and perhaps once more
# to sound at g "
# rd in oreb since perhaps
# when god descended, and perhaps once more
# to sound at gent we from the still heav’n the stand,
# not with seemd and more on the grown of the thee farr down to this first the seemd creature the great the self find as in we heav’ns the heav’ns and drow the te
# Temperature: 1.0
# Generating with starting sequence: " d
# of dulcet symphonies and voices sweet,
# built like a temple, where pilasters ro "
# d
# of dulcet symphonies and voices sweet,
# built like a temple, where pilasters romal to ise to thele at this sidge what wing, and then a lop’d bling me on pain to each he ourfenate, yet cass
# in rust and toniature
# groon whose wat’d leave,
# onsless fard, thy suptey whose by nume is m
#
# Epoch 4
# Epoch 1/1
# 151204/151204 [==============================] - 242s 2ms/step - loss: 1.7558
#
# Temperature: 0.2
# Generating with starting sequence: "  that equal lot
# may joyne us, equal joy, as equal love;
# least thou not tasting,  "
#  that equal lot
# may joyne us, equal joy, as equal love;
# least thou not tasting, and so the seems, and his with his seemd and the state the starrs thir strange, and the sound the seemd with the stream
# the seed the seems the son the seemd the seemd the son the seemd the son the see
# Temperature: 0.5
# Generating with starting sequence: " he waste
# wide anarchie of chaos damp and dark
# flew divers, and with power (thir  "
# he waste
# wide anarchie of chaos damp and dark
# flew divers, and with power (thir may with with thy wick the eve of thir him fliest hold the stood the sin hath shall the wimes the sun be whom he state with which the the that the self of hell him the mortal with the seemd still the
# Temperature: 1.0
# Generating with starting sequence: " ,
# then first with fear surpris’d and sense of paine
# fled ignominious, to such ev "
# ,
# then first with fear surpris’d and sense of paine
# fled ignominious, to such evport with anclorbt of hill rateus,
# against saver, what her grute
# him his hid found other pearlitus: then not; the purstiul bost weav’n timphal father, wove to me at dirous beot
# theminds, drost,
# with e
#
# Epoch 5
# Epoch 1/1
# 151204/151204 [==============================] - 246s 2ms/step - loss: 1.7273
#
# Temperature: 0.2
# Generating with starting sequence: " borne,
# before the hills appeerd, or fountain flow’d,
# thou with eternal wisdom di "
# borne,
# before the hills appeerd, or fountain flow’d,
# thou with eternal wisdom discome the seemd the surber the compute the seemd the starr
# the surber the seems the seemd the seemd the sure the seemd the seemd the seemd the seemd the seems the strong the seemd the seemd the seemd
# Temperature: 0.5
# Generating with starting sequence: " both turnd, and under op’n skie ador’d
# the god that made both skie, air, earth a "
# both turnd, and under op’n skie ador’d
# the god that made both skie, air, earth and be discomperst the fame,
# the the strong
# of heav’n so from the sould compose the fierce of heav’n strough the gall him be the tript some with the suffect from heard repast all his heard round the ro
# Temperature: 1.0
# Generating with starting sequence: "  as a mount
# rais’d on a mount, with pyramids and towrs
# from diamond quarries hew "
#  as a mount
# rais’d on a mount, with pyramids and towrs
# from diamond quarries hew, ere
# the  hours strail offymbrigst gast tears thee whenceforth recete
# my more then restares
# lidg
# i chift,
# at thir spoidd
# mediew,
# there neature to pariot, thir ty and his gods, thus self air rent heav
#
# Epoch 6
# Epoch 1/1
# 151204/151204 [==============================] - 243s 2ms/step - loss: 1.7053
#
# Temperature: 0.2
# Generating with starting sequence: " o whom the virgin majestie of eve,
# as one who loves, and some unkindness meets,
#  "
# o whom the virgin majestie of eve,
# as one who loves, and some unkindness meets,
# the seemd and man of the ground the spake, the for the seemd the speed of the speed and the seemd and the speed the seems the streams the speed and farr of the secrest the speek in the speek
# and the s
# Temperature: 0.5
# Generating with starting sequence: " , and in dreadful deeds
# fearless, endanger’d heav’ns perpetual king;
# and put to  "
# , and in dreadful deeds
# fearless, endanger’d heav’ns perpetual king;
# and put to the ground, now the seat stribess the starr; the deparies, and each the proscion of last and with each of ever, the spake the to our love and taste them had long his sons all the tree, whom the prosec
# Temperature: 1.0
# Generating with starting sequence: "  wise.
# but if the sense of touch whereby mankind
# is propagated seem such dear de "
#  wise.
# but if the sense of touch whereby mankind
# is propagated seem such dear depayle rangel kebl
# oath: suppenief haft of sdavour ssehement
# unsoughts farrs upultry sacrh pamid we inour newign authing rther a desenter? and his with life: and detand a of thought him to the complet
#
#
# Epoch 7
# Epoch 1/1
# 151204/151204 [==============================] - 242s 2ms/step - loss: 1.6879
#
# Temperature: 0.2
# Generating with starting sequence: " amidst
# the garden, god hath said, ye shall not eate
# thereof, nor shall ye touch  "
# amidst
# the garden, god hath said, ye shall not eate
# thereof, nor shall ye touch and seemd the force the seemd
# the seemd and seemd the seemd the stand the seemd the seemd the seemd the seemd the seemd the seemd the seems and the forth the seems of heav’n, and seemd the seek and se
# Temperature: 0.5
# Generating with starting sequence: " nd none, so thick entwin’d,
# as one continu’d brake, the undergrowth
# of shrubs an "
# nd none, so thick entwin’d,
# as one continu’d brake, the undergrowth
# of shrubs and self the said
# of heav’ns with from the destroke and mean with love the part solemphis god enceave the seek
# before of the god and found thy will and had from the attempt the tround into sons to sight
# Temperature: 1.0
# Generating with starting sequence: " urn
# his odious offrings, and adore the gods
# whom he had vanquisht. after these a "
# urn
# his odious offrings, and adore the gods
# whom he had vanquisht. after these as none on him imangues, nor powers repfin’d;
# comited to will in anciept
# aided aok to him avov’d unpare their lawes,
# and fieldeteriel mute all aour jeavd; saws,
# not of the an his his ferter wanting, os
#
# Epoch 8
# Epoch 1/1
# 151204/151204 [==============================] - 209s 1ms/step - loss: 1.6704
#
# Temperature: 0.2
# Generating with starting sequence: " saild,
# that scorn’d his indignation: through the gate,
# wide open and unguarded,  "
# saild,
# that scorn’d his indignation: through the gate,
# wide open and unguarded, and seemd the self the stand the stroke
# of the self the self the self the self the starr the form
# the self the self the self the self the stroke
# all the self the self the seemd the self the seemd
# the
# Temperature: 0.5
# Generating with starting sequence: " ’d
# benevolent and facil thus repli’d.
#
# to ask or search i blame thee not, for he "
# ’d
# benevolent and facil thus repli’d.
#
# to ask or search i blame thee not, for heav’n, and still and the treach
# the tree the arm’d, and less of me the shall mate
# all the shall regant starr the in the seemd
# a far i shall land things compar’d
# of his world of the self of heav’n
# was t
# Temperature: 1.0
# Generating with starting sequence: " y string or golden wire
# temper’d soft tunings, intermixt with voice
# choral or un "
# y string or golden wire
# temper’d soft tunings, intermixt with voice
# choral or unface on his eres in the ground
# their harbiers end
# us yet this man chaid
# up receiv’d there the hasters not
# might airs; and his trussibous felt
# we laving numeriel ineperaast; and hust beign the heav’n s
#
# Epoch 9
# Epoch 1/1
# 151204/151204 [==============================] - 216s 1ms/step - loss: 1.6486
#
# Temperature: 0.2
# Generating with starting sequence: " onder, that all nations of the earth
# shall in his seed be blessed; by that seed
#  "
# onder, that all nations of the earth
# shall in his seed be blessed; by that seed
# the sea the seemd the seemd and the seemd
# of the seemd the sought the place of the seemd
# of paine the seemd and the seemd and in heav’n,
# and the seems of the seemd the seemd and the seemd
# of soon the
# Temperature: 0.5
# Generating with starting sequence: " hose tents thou sawst so pleasant, were the tents
# of wickedness, wherein shall d "
# hose tents thou sawst so pleasant, were the tents
# of wickedness, wherein shall dayes the morn
# and the vertue and dine of his way
# in of heav’n, and will the from the raise
# of god who shall in the fiend, and longs of mankinde
# of the plute arming the great repli’d.
# but and to the se
# Temperature: 1.0
# Generating with starting sequence: " n all sides round
# as one great furnace flam’d, yet from those flames
# no light, b "
# n all sides round
# as one great furnace flam’d, yet from those flames
# no light, but be leach centanions so
# is o for heaven
# then am unrund, and here, and i night o’re be desmit roses,
# and desolaynd the stwentrests of last their night,s live,
# rupe, when thus above and laves
# /home/tadeas/anaconda3/envs/tensorflow/lib/python3.6/site-packages/ipykernel_launcher.py:8: RuntimeWarning: divide by zero encountered in log
# , or the
#
# Epoch 10
# Epoch 1/1
# 151204/151204 [==============================] - 194s 1ms/step - loss: 1.6330
#
# Temperature: 0.2
# Generating with starting sequence: "  art heav’nlie, shee an empty dreame.
#
# say goddess, what ensu’d when raphael,
# th "
#  art heav’nlie, shee an empty dreame.
#
# say goddess, what ensu’d when raphael,
# this seems the seemd the seemd the ground
# and the seemd the seemd the seems of heav’n,
# and some the seems the seems the seems
# the some the seems the sea the seems of heav’n,
# and the seems the seemd and
# Temperature: 0.5
# Generating with starting sequence: " uldst my firmness therefore doubt
# to god or thee, because we have a foe
# may temp "
# uldst my firmness therefore doubt
# to god or thee, because we have a foe
# may temper in in heav’n, and the remov’d
# all leaded thou persibise, and begin
# the second thir spoise of in the god
# i many with thir battel first half leose and let the more,
# shall and the provids, and sons, t
# Temperature: 1.0
# Generating with starting sequence: " continual watch
# our great forbidder, safe with all his spies
# about him.  but to  "
# continual watch
# our great forbidder, safe with all his spies
# about him.  but to among faces, who flight be set
# thy fruit, nole? to enter rord
# the confusie hill; of sines ealted our shold
# yet be of him he manmence, not sign’d
# with ridy was while region
# agming the disarge fathers a
#
# Epoch 11
# Epoch 1/1
# 151204/151204 [==============================] - 205s 1ms/step - loss: 1.6245
#
# Temperature: 0.2
# Generating with starting sequence: " receives them right,
# had need from head to foot well understand;
# not understood, "
# receives them right,
# had need from head to foot well understand;
# not understood, and the speed and to the seems
# the self the self the sons of the self the step to the sernes
# of the self the tranger the morn
# the self the self the self the seat the self the gree
# the sons of the sel
# Temperature: 0.5
# Generating with starting sequence: "  pluck such choice
# to entertain our angel guest, as hee
# beholding shall confess  "
#  pluck such choice
# to entertain our angel guest, as hee
# beholding shall confess the warring his may of my greet;
# the perceal reason of this self,
# such the on the strive he connain
# soon autiage thir him was a all the serpent
# so refent him to not consting the seems
# his part of the
# Temperature: 1.0
# Generating with starting sequence: " rough him, but th’ ethereal substance clos’d
# not long divisible, and from the ga "
# rough him, but th’ ethereal substance clos’d
# not long divisible, and from the gard;
# of they laid must eep, and eve
# with god lite they makie vacious of dreame,
# and teven wouldss in by top in emse:
# if panc’t, when and my gak’d those part making
# i the knows by no strict
# whom wave, w
#
# Epoch 12
# Epoch 1/1
# 151204/151204 [==============================] - 203s 1ms/step - loss: 1.6159
#
# Temperature: 0.2
# Generating with starting sequence: "  glorie account,
# my exaltation, and my whole delight,
# that thou in me well pleas "
#  glorie account,
# my exaltation, and my whole delight,
# that thou in me well pleasure to the sin his seemd
# the spares and the seemd the seemd
# the sould the seemd the sould the seemd
# the seemd the seemd the seemd the supperd the seemd
# the seemd and the seemd the sould the son
# the se
# Temperature: 0.5
# Generating with starting sequence: "  those bright luminaries
# officious, but to thee earths habitant.
# and for the hea "
#  those bright luminaries
# officious, but to thee earths habitant.
# and for the heads with battel worshall dire
# to to thir about thir more the seath my broome
# the live had since receiv’d with thir grace
# so seemd his head this laid, and ended fame
# and thir round holide and for delive
# Temperature: 1.0
# Generating with starting sequence: " xe, ye powers of heav’n,
# and thou my word, begotten son, by thee
# this i perform, "
# xe, ye powers of heav’n,
# and thou my word, begotten son, by thee
# this i perform, there, his folled that back.
# till steod beholds post evil world chance or daile,
# what impulted sippirad, who best, high him race admivie his brought
# of death; where with deemd
# us grodierar to goynd p
#
# Epoch 13
# Epoch 1/1
# 151204/151204 [==============================] - 200s 1ms/step - loss: 1.6097
#
# Temperature: 0.2
# Generating with starting sequence: " ate; hee together calls,
# or several one by one, the regent powers,
# under him reg "
# ate; hee together calls,
# or several one by one, the regent powers,
# under him regions the transt the seemd
# the god the seems the seemd the seems the seems
# the seemd the greeper the fall’ns of the seems
# of heav’n, and the seems the tree the seems
# the self the place the seemd the se
# Temperature: 0.5
# Generating with starting sequence: " when the fierce foe hung on our brok’n rear
# insulting, and pursu’d us through th "
# when the fierce foe hung on our brok’n rear
# insulting, and pursu’d us through the bring
# the deep, that the state, what the seem,
# the in things in dispaine the sons whose supper’d
# of might destruct many have glorie, and the come
# the spirit human shall and sublight the son
# the seem
# Temperature: 1.0
# Generating with starting sequence: "  so steers, and shifts her saile;
# so varied hee, and of his tortuous traine
# curl "
#  so steers, and shifts her saile;
# so varied hee, and of his tortuous traine
# curlows; this streak to the life how thought the nature uncount
# they hid tribliel mov’d what covers round their and propess
# the carm on heav’ns from what giveous areful then all the have or native,
# if elv
#
# Epoch 14
# Epoch 1/1
# 151204/151204 [==============================] - 191s 1ms/step - loss: 1.6001
#
# Temperature: 0.2
# Generating with starting sequence: " of her beauty and submissive charms
# smil’d with superior love, as jupiter
# on jun "
# of her beauty and submissive charms
# smil’d with superior love, as jupiter
# on junger the seems and the sease the seemd
# the seemd and self the seems of the seas
# the starr the seas of the seal to the strice
# and state the seemd the first the seems
# of the stood the seems the stood the
# Temperature: 0.5
# Generating with starting sequence: " ter’d arms and ensigns, till anon
# his swift pursuers from heav’n gates discern
# t "
# ter’d arms and ensigns, till anon
# his swift pursuers from heav’n gates discern
# the happie perter and farr the ground.
# or the seems and thir procean all heav’ns one
# the all the world have the suppertion stand
# at hell her continan words his still,
# or with one to the faith, and the
# Temperature: 1.0
# Generating with starting sequence: " dly i groane;
# while they adore me on the throne of hell,
# with diadem and scepter "
# dly i groane;
# while they adore me on the throne of hell,
# with diadem and scepters on life; one off
# all thy easing with stood charious liest?
# thou as thas and shale might cret such the bright ude
# scorning heav’ns of flouring the armimst
# he the pursewor was which power
# from all sta
#
# Epoch 15
# Epoch 1/1
# 151204/151204 [==============================] - 186s 1ms/step - loss: 1.5934
#
# Temperature: 0.2
# Generating with starting sequence: " s still
# to give us onely good; and if the night
# have gathered aught of evil or c "
# s still
# to give us onely good; and if the night
# have gathered aught of evil or confetie seems
# the great the seems of the seems the seems
# the seems of the seemd the seems of the seems
# and the seemd the seems of the seems the seems
# and son the seems and descent soon the seed
# the se
# Temperature: 0.5
# Generating with starting sequence: " toward the gates of hell
# explores his solitary flight; som times
# he scours the r "
# toward the gates of hell
# explores his solitary flight; som times
# he scours the returnd with all the wheeless the seek
# the shall the spread the gates of the seemd
# to a mean warrs the sears and speed
# the second potent and self, where all lead,
# the him farr was with son and heav’n,
#
# Temperature: 1.0
# Generating with starting sequence: "  success,
# throws his steep flight with many an aerie wheele,
# nor staid, till on  "
#  success,
# throws his steep flight with many an aerie wheele,
# nor staid, till on lives, or his eyes
# hall appeaencts that see
# he embreathon wown
# his pain’d his hands, reinance to his power.
# which bestood on, afterd, for this joying west how
# hands him other death the each
# call’d as
#
# Epoch 16
# Epoch 1/1
# 151204/151204 [==============================] - 170s 1ms/step - loss: 1.5903
#
# Temperature: 0.2
# Generating with starting sequence: " blissful bower; it was a place
# chos’n by the sovran planter, when he fram’d
# all  "
# blissful bower; it was a place
# chos’n by the sovran planter, when he fram’d
# all the seemd the seemd the seemd
# and the seemd and the starr to the seemd
# the seemd the seemd the self the self stood
# the seemd the second the seemd of heav’n,
# where the strict of the seemd and such the
# Temperature: 0.5
# Generating with starting sequence: " turne
# of them derided, but of god observd
# the one just man alive; by his command "
# turne
# of them derided, but of god observd
# the one just man alive; by his command the prose
# race not of fair in sumpless shall way the sons
# in the second had the solliture with all the morn
# better reason, and force great of the seemd
# and armiss the morn his grace, and the come
# the
# Temperature: 1.0
# Generating with starting sequence: " n and grave, with warriours mixt,
# assemble, and harangues are heard, but soon
# in "
# n and grave, with warriours mixt,
# assemble, and harangues are heard, but soon
# intended wing; and less and charm mute,
# prosporaft, then alcetief forch: soon perfure;
# this endising cat thus heart deficcon;
# for thee lengge sacurwic gretg, what runch,
# and and bod davisible of assecti
#
# Epoch 17
# Epoch 1/1
# 151204/151204 [==============================] - 169s 1ms/step - loss: 1.5828
#
# Temperature: 0.2
# Generating with starting sequence: " ure of harme.
# this eevning from the sun’s decline arriv’d
# who tells of som infer "
# ure of harme.
# this eevning from the sun’s decline arriv’d
# who tells of som infernal the seems of the seems
# of the self and the self and the seems and shall seed
# the self and the sease the self the self the self,
# and the self the seat the seat or self and shall stream
# the seems of
# Temperature: 0.5
# Generating with starting sequence: " , and shoales
# of fish that with thir finns and shining scales
# glide under the gr "
# , and shoales
# of fish that with thir finns and shining scales
# glide under the grace or live, and meet or spake.
#
# the starr, and what and the creation shall sight
# and live the sea, and the heav’ns of the seemd
# and the grave with th’ angel stand the seems
# of prodemption entermies o
# Temperature: 1.0
# Generating with starting sequence: " s: when by command
# moses once more his potent rod extends
# over the sea; the sea  "
# s: when by command
# moses once more his potent rod extends
# over the sea; the sea the sight.  thou stande
# rother forth hell and light and sing,
# or if a changes works, well my godsive welpe?
# was sole there power encempt chard
# best, to outward with the deep
# the call’d whereey his cou
#
# Epoch 18
# Epoch 1/1
# 151204/151204 [==============================] - 170s 1ms/step - loss: 1.5842
#
# Temperature: 0.2
# Generating with starting sequence: "  can will serve,
# that little which is left so to defend
# encroacht on still throu "
#  can will serve,
# that little which is left so to defend
# encroacht on still through the heav’ns the seat
# the seems of heav’nly strength and heav’nly shall so seems
# the self the his stranger the strength
# the self the seat with the seat the self the seat
# the self of the self and may
# Temperature: 0.5
# Generating with starting sequence: " rav’d,
# justice and temperance, truth and faith forgot;
# one man except, the onely "
# rav’d,
# justice and temperance, truth and faith forgot;
# one man except, the onely stood i sut beast
# right that inceard all the sear from the more
# heard of him man be smil’d, and unlight
# and have with the foretonest can tastest the sent.
# the sun the seat of first all the self almig
# Temperature: 1.0
# Generating with starting sequence: " arce
# had ended; when to right and left the front
# divided, and to either flank re "
# arce
# had ended; when to right and left the front
# divided, and to either flank reard
# of powere, for he rather, suffer hell tre of mate
# that of pan lipake abders of heav’n,
# though heav’nly custal seest and suprodion horrows
# and inlet camtows of thir cionculion stood wag:
# so whom ou
#
# Epoch 19
# Epoch 1/1
# 151204/151204 [==============================] - 170s 1ms/step - loss: 1.5806
#
# Temperature: 0.2
# Generating with starting sequence: " reator calling forth by name
# his mightie angels gave them several charge,
# as sor "
# reator calling forth by name
# his mightie angels gave them several charge,
# as sorrow the self and fair the seems the stree
# the self the stor’d, and the more not stream
# the seemd the seems the sons the seems
# of heav’n of the seems the seems the seems
# and sin and seems the seems of
# Temperature: 0.5
# Generating with starting sequence: " and lasting pain
# torments him; round he throws his baleful eyes
# that witness’d h "
# and lasting pain
# torments him; round he throws his baleful eyes
# that witness’d his land the seems his starr
# to thy ground of place, which the most faires,
# and hour, and the stor’d, and heav’ns the self
# thir streatn, though for stood the tents,
# and with god and seems and self,
# and
# Temperature: 1.0
# Generating with starting sequence: " multiplies
# her fertil growth, and by disburd’ning grows
# more fruitful, which ins "
# multiplies
# her fertil growth, and by disburd’ning grows
# more fruitful, which inselfilal;
#
# i sight, stor’d and paradise on stood
# the proofficaty onely aight, and stand,
# thus now so fleaging deit, and inspects,
# and noil, longak’ning stood hell
# of gods my off.  all him, i:
# i movie f
#
# Epoch 20
# Epoch 1/1
# 151204/151204 [==============================] - 170s 1ms/step - loss: 1.5791
#
# Temperature: 0.2
# Generating with starting sequence: "
# neither our own but giv’n; what follie then
# to boast what arms can doe, since t "
#
# neither our own but giv’n; what follie then
# to boast what arms can doe, since the seems
# the self and seems the seems the seems, and seems
# the seems the seems the seems the seems the self
# the self and sea, and the seems the self,
# the low the self of the seemd of heav’n
# the self t
# Temperature: 0.5
# Generating with starting sequence: " o god-head, with more strength to foil
# thy enemie; nor so is overcome
# satan, who "
# o god-head, with more strength to foil
# thy enemie; nor so is overcome
# satan, who the self the spake, the seem’d
# the wilder then of this place his words
# in the troubtion her substine, and the mine,
# so advance, thou the tree the sea and suttere cave
# for heav’n the more the sight be
# Temperature: 1.0
# Generating with starting sequence: " ft onely in those written records pure,
# though not but by the spirit understood. "
# ft onely in those written records pure,
# though not but by the spirit understood.
# they all his cifereie of this i the like
# aroof and noperton he sweet of his mode
# have last and vertuet louds, or abrial,
# or with temptied field with mount to loot
# so keep, for cast of spads, the shom
#
# Epoch 21
# Epoch 1/1
# 151204/151204 [==============================] - 170s 1ms/step - loss: 1.5787
#
# Temperature: 0.2
# Generating with starting sequence: "  haste
# among sweet dewes and flours; where any row
# of fruit-trees overwoodie rea "
#  haste
# among sweet dewes and flours; where any row
# of fruit-trees overwoodie reason and hath the since
# to land the self the sea the sease, and sin the stream
# he satan stranger the sease with the spake.
#
# the sons to the seed the sea, and with head
# to the self and the strange of he
# Temperature: 0.5
# Generating with starting sequence: " ld west was set
# his mirror, with full face borrowing her light
# from him, for oth "
# ld west was set
# his mirror, with full face borrowing her light
# from him, for other the sent, and the exceld
# and me at the troubting fair the charge
# encreature with haste better stream to world
# the fair to the sound they destruct,
# and glory and thir stores of the tree
# the faire, a
# Temperature: 1.0
# Generating with starting sequence: "
# but silently a gentle tear let fall
# from either eye, and wip’d them with her ha "
#
# but silently a gentle tear let fall
# from either eye, and wip’d them with her haste,
# adam harr of thy good high
# herlous a fled me beings, thir bin drive of rease
# buinting for head
# withoutfuling ye of his flated li’d.
# that warring evil ought, forth messible
# of morrafeet more bee h
#
# Epoch 22
# Epoch 1/1
# 151204/151204 [==============================] - 170s 1ms/step - loss: 1.5743
# Temperature: 0.2
# Generating with starting sequence: "  heard, and hast not fear’d,
# but still rejoyc’t, how is it now become
# so dreadfu "
#  heard, and hast not fear’d,
# but still rejoyc’t, how is it now become
# so dreadful the seems the self the seems the self the seemd
# of the self the self the self and songs of heav’n,
# and some the self the self the self the self the self
# the self the self the seems the sea the self
# Temperature: 0.5
# Generating with starting sequence: "  shrub,
# and bush with frizl’d hair implicit: last
# rose as in dance the stately t "
#  shrub,
# and bush with frizl’d hair implicit: last
# rose as in dance the stately thou the bliss of heav’n;
# the with else the power and then the swarmd
# the self and in the power of heav’n, though the shalt with grow
# of heav’n new world remove works thee seemd
# cronged in the earth th
# Temperature: 1.0
# Generating with starting sequence: " uce new worlds; whereof so rife
# there went a fame in heav’n that he ere long
# int "
# uce new worlds; whereof so rife
# there went a fame in heav’n that he ere long
# into the solst whom on me waves, that took or all.
# thou now seems earth angel mee commind, the was with thy power,
# and binds we godeds from now, and destrooft and nightius compart
# in heav’n, in thou alge
#
# Epoch 23
# Epoch 1/1
# 151204/151204 [==============================] - 169s 1ms/step - loss: 1.5731
#
# Temperature: 0.2
# Generating with starting sequence: " nd eyes, new hopes, new joyes,
# taste so divine, that what of sweet before
# hath t "
# nd eyes, new hopes, new joyes,
# taste so divine, that what of sweet before
# hath the son and the seen and the seat
# her string the seave the seave of the seave
# of heav’n and the more of god, and son
# and the seas the shall the seat the seave
# the seen the seavie shall the son the seat
# Temperature: 0.5
# Generating with starting sequence: " urs
# her self a fairer floure by gloomie dis
# was gatherd, which cost ceres all th "
# urs
# her self a fairer floure by gloomie dis
# was gatherd, which cost ceres all the ended
# not son and proportuted less the flours great more
# of pabring throne in his pure, the faire
# of but farr of the streams the slate
# to light let the sungs, sat her fair the world
# the world, where
# Temperature: 1.0
# Generating with starting sequence: "  edge came down
# wide wasting; such destruction to withstand
# he hasted, and oppos "
#  edge came down
# wide wasting; such destruction to withstand
# he hasted, and oppos’d: while riches i by exampile
# of of his troubting down, in best
# met for reason was wav. imbuck good,
# plish to the side if the gorge wilde
# to sup one, none know-rapes, and sid
# confurns, not who but ca
#
# Epoch 24
# Epoch 1/1
# 151204/151204 [==============================] - 184s 1ms/step - loss: 1.5716
#
# Temperature: 0.2
# Generating with starting sequence: " he had vanquisht. after these appear’d
# a crew who under names of old renown,
# osi "
# he had vanquisht. after these appear’d
# a crew who under names of old renown,
# osie and the serve the sea, and the sea
# the grown, and the self the sea, and the self
# the suffer the self the fiend the sease
# the self and the self and the self the self
# the sea the sent and the self the
# Temperature: 0.5
# Generating with starting sequence: " eas
# beyond th’ horizon; then from pole to pole
# he views in bredth, and without l "
# eas
# beyond th’ horizon; then from pole to pole
# he views in bredth, and without life
# commons to his envil round, and and each
# and place his supsent will and lost
# the life shall with the way with pass’d
# the sound with the who the morn, and of seed
# the self all the fair despair
# his
# Temperature: 1.0
# Generating with starting sequence: " t; where it stood retir’d
# from off the files of warr; there they him laid
# gnashi "
# t; where it stood retir’d
# from off the files of warr; there they him laid
# gnashing for fell, reniet broath or they returt
# be, and to honads of the earth,
# leap what at the sconetchy glory one bring
# pertwy oretantieful of shall tine shall hope
# seek this man of his rais’d honour wit
#
# Epoch 25
# Epoch 1/1
# 151204/151204 [==============================] - 204s 1ms/step - loss: 1.5751
#
# Temperature: 0.2
# Generating with starting sequence: " he burd’n of many ages, on me light
# at once, by my foreknowledge gaining birth
# a "
# he burd’n of many ages, on me light
# at once, by my foreknowledge gaining birth
# and the self to the provicious contrance when the seemd
# and the seat the seat the sould the seemd
# the seat the self and the seat the self and the supples
# the self and the sent, and the sound the seat
# t
# Temperature: 0.5
# Generating with starting sequence: "  in swift race contend,
# as at th’ olympian games or pythian fields;
# part curb th "
#  in swift race contend,
# as at th’ olympian games or pythian fields;
# part curb thir is long in the converd
# the hard satan debatters on the treat who the instroy.
# this open when a to long to warrs in all man,
# so sung on the shall replying, and in the envince,
# and the scepter more a
# Temperature: 1.0
# Generating with starting sequence: " om all heav’ns bounds into the utter deep:
# there let them learn, as likes them,  "
# om all heav’ns bounds into the utter deep:
# there let them learn, as likes them, but pursue
# where free tavore diabour prosib, seek redur.
#
# nor waying, and air nopdent began.
#
# he my suvil, sudge hee, and earth, and be
# all hath his made sound heav’n none uncerme,
# might just rance ef
#
# Epoch 26
# Epoch 1/1
# 151204/151204 [==============================] - 202s 1ms/step - loss: 1.5724
#
# Temperature: 0.2
# Generating with starting sequence: " ie sole among
# the infernal powers, in one day to have marr’d
# what he almightie s "
# ie sole among
# the infernal powers, in one day to have marr’d
# what he almightie some so seems the seems with the seek
# to his the sung to the like the seemd
# of heav’n and seemd with the seemd the serve
# the sense the seemd the seemd the seems of these
# the good the seemd the seems an
# Temperature: 0.5
# Generating with starting sequence: " poser, what thou bidst
# unargu’d i obey; so god ordains,
# god is thy law, thou min "
# poser, what thou bidst
# unargu’d i obey; so god ordains,
# god is thy law, thou minder thee, winds,
# and the seply to from heav’n and feile,
# with ever ere night sto his life,
# or to his charted som heav’n to the remove
# the spease of god with his bread a discompar’d
# those wing, the les
# Temperature: 1.0
# Generating with starting sequence: " able shape;
# the one seem’d woman to the waste, and fair,
# but ended foul in many  "
# able shape;
# the one seem’d woman to the waste, and fair,
# but ended foul in many dhranged, sang eve
# estm’d, perhaps tein’d sole comes the subprew
# from seft hose water’d more him gold to last
# to sea here so retor’d i bruises lier;
# meanunalts, with flockt of tim’st, when
# bayn and w
#
# Epoch 27
# Epoch 1/1
# 151204/151204 [==============================] - 183s 1ms/step - loss: 1.6506
#
# Temperature: 0.2
# Generating with starting sequence: " ght
# from pole to pole, traversing each colure;
# on the eighth return’d, and on th "
# ght
# from pole to pole, traversing each colure;
# on the eighth return’d, and on the forth the seat
# the starr of heav’ns of heav’ns the gods of the greep
# the seat the speed the great seems, and state
# the sease of the compar’d the seare the seat
# the self of the sease of the seat
# to t
# Temperature: 0.5
# Generating with starting sequence: "  the gate
# with dreadful faces throng’d and fierie armes:
# som natural tears they  "
#  the gate
# with dreadful faces throng’d and fierie armes:
# som natural tears they suns of darkness forth
# the starr that state of the gods the since thou fee
# and desire to death and from the hears
# in hast to darkness of compard shade;
# the sight at have still works, and from heav’n,
#
# Temperature: 1.0
# Generating with starting sequence: " ugh through mazes, lead me still
# but to my own conviction: first and last
# on mee "
# ugh through mazes, lead me still
# but to my own conviction: first and last
# on mee to was he chantent; but thee,
# and passute the maoes.  thou might,
# sain manity prace this well end
# bedopions or maker, unonely underculs
# place, and bring on helf thus fould,
# ktodied return, who vost j
#
# Epoch 28
# Epoch 1/1
# 151204/151204 [==============================] - 172s 1ms/step - loss: 1.6134
#
# Temperature: 0.2
# Generating with starting sequence: " ad the spring
# perpetual smil’d on earth with vernant flours,
# equal in days and n "
# ad the spring
# perpetual smil’d on earth with vernant flours,
# equal in days and not the sease the seat
# the sent and starr the seat the seat
# the send and sun the stor’d the sease,
# and so stand the seat the seat, and the seat
# the sent the seat the seat the seat the sent
# to the son t
# Temperature: 0.5
# Generating with starting sequence: " delay to heare thee tell
# his generation, and the rising birth
# of nature from the "
# delay to heare thee tell
# his generation, and the rising birth
# of nature from the spirits thir chances of the earth
# she spake, and the son, but the seat
# of shall the stright and the beast your seat of the wing
# with his gast of the confernal seems,
# whose not starr of his in the day
# Temperature: 1.0
# Generating with starting sequence: " rs,
# vvith other echo farr i taught your shades
# to answer, and resound farr other "
# rs,
# vvith other echo farr i taught your shades
# to answer, and resound farr others, also tright
# harpuc, and spak’t; and the his peruent.
#
# on thou the many abichs who man
# obpras’d
# fell mains uncoke as free.  thou to pay,
# not want to thing ye who’se knoane.
# deshall his anlengal’d, a
#
# Epoch 29
# Epoch 1/1
# 151204/151204 [==============================] - 171s 1ms/step - loss: 1.5663
#
# Temperature: 0.2
# Generating with starting sequence: " ted, they may finde
# justification towards god, and peace
# of conscience, which th "
# ted, they may finde
# justification towards god, and peace
# of conscience, which the sons of heav’n,
# the seat of the fire the sound the seemd
# of the seat of heav’n of the seat
# the sound the sea, and the sound the seemd
# the seat of heav’n, and the seat, and the seat
# the sound of heav
# Temperature: 0.5
# Generating with starting sequence: " ll him, brighter once amidst the host
# of angels, then that starr the starrs amon "
# ll him, brighter once amidst the host
# of angels, then that starr the starrs among heav’n
# in heav’n, and his man fould shows and in the counsers adorn
# from the sea as gate of pastion starr the pain
# more distempting shame of the suns the grows
# such and like of the seemd with name,
# Temperature: 1.0
# Generating with starting sequence: " for so i undertook
# before thee; and not repenting, this obtaine
# of right, that i "
# for so i undertook
# before thee; and not repenting, this obtaine
# of right, that infinit brrace till, clud
# with host love or thee real’d of mires.
# this one first mens heyes of dainage, of the both,
# choits declaust; but rim’d thou up; which he shapes
# by at pain to eve cunpraited fir
